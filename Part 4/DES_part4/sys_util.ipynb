# %% [markdown]
# # System throughput vs rho, sim_time

# %%
# %matplotlib inline

# %%
import part3_simstudy

# %%
part3_simstudy.draw_hist_util()
# Out:
# ___________________________
# rho is 0.01
# sim_time is 100
# Mean utilization is 0.00992379622529
# sim_time is 1000
# Mean utilization is 0.010048472815
# sim_time is 10000
# Mean utilization is 0.0100110420459
# ___________________________
# rho is 0.5
# sim_time is 100
# Mean utilization is 0.499620000147
# sim_time is 1000
# Mean utilization is 0.493350968177
# sim_time is 10000
# Mean utilization is 0.496281350251
# ___________________________
# rho is 0.8
# sim_time is 100
# Mean utilization is 0.751056870865
# sim_time is 1000
# Mean utilization is 0.747457279275
# sim_time is 10000
# Mean utilization is 0.747050187821
# ___________________________
# rho is 0.9
# sim_time is 100
# Mean utilization is 0.808746402526
# sim_time is 1000
# Mean utilization is 0.80072188165
# sim_time is 10000
# Mean utilization is 0.808514687733

# %% [markdown]
# # system throughput, dropping rate vs queue size

# %%
part3_simstudy.draw_queue_size_vs_throughput()
